# %% [markdown]
# # **Ernesto Gurgel Valente Neto**
#
# ---
# # **Materia: Analise de Dados Textuais**
#
#
# ---
#
# Prof: Wellington

# %%
print('Importação de Pacotes')
import nltk
import re
nltk.download('gutenberg')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# Importação de Pacotes
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# # 1) Para o corpus “shakespeare-caesar.txt”, usando expressões
# regulares responda os seguintes itens: **texto em negrito**

# %%
caesar = nltk.corpus.gutenberg.words('shakespeare-caesar.txt')

# %% [markdown]
# # **a) Quantidades de palavras que terminam com “r”;**

# %%
#procura dados casados
#re.fullmatch()
#buscar determinado padrao ou contexto
#re.search()

# %%
lista_word_r = []
for word in caesar:
  if re.search("r$",word):
    lista_word_r.append(word)

# %%
#lista_word_r

# %%
print('Tamanho da Quantidade de palavras que terminam com R:', len(lista_word_r))
# Out:
# Tamanho da Quantidade de palavras que terminam com R: 1322

# %% [markdown]
# # **b) Quantidade de palavras com 5 letras;**

# %%
lista_word_5 = []
for word in caesar:
  if re.search("^.....",word):
    lista_word_5.append(word)

# %%
#lista_word_5

# %%
print('Tamanho da Quantidade de palavras que terminam com 5 letras:', len(lista_word_5))
# Out:
# Tamanho da Quantidade de palavras que terminam com 5 letras: 7214

# %% [markdown]
# # **c) Quantidade de vezes que “err” ocorre no corpus;**

# %%
lista_word_err = []
for word in caesar:
  if re.search("err",word):
    lista_word_err.append(word)

# %%
#lista_word_err

# %%
print('Tamanho da Quantidade de palavras que terminam com err:', len(lista_word_err))
# Out:
# Tamanho da Quantidade de palavras que terminam com err: 13

# %% [markdown]
# # **d) Quantidade de vezes que “are” ocorre no corpus para as palavras com 5 ou mais caracteres.**

# %%
lista_word_are1 = []
for word in caesar:
  if re.search("are..",word):
    lista_word_are1.append(word)
lista_word_are2 = []
for word in caesar:
  if re.search(".are.",word):
    lista_word_are2.append(word)
lista_word_are3 = []
for word in caesar:
  #sinal + Check if the string contains followed by 1 or more "x" characters:
  if re.search("^.*are.*$",word):
    lista_word_are3.append(word)

x1 = len(lista_word_are1)
x2 = len(lista_word_are2)
x3 = len(lista_word_are3)

# %%
#lista_word_are1
#lista_word_are2
#lista_word_are3

# %%
print('Tamanho da Quantidade de palavras que terminam com are com 5 ou mais palavras:', x1+x2+x3)
# Out:
# Tamanho da Quantidade de palavras que terminam com are com 5 ou mais palavras: 344

# %% [markdown]
# # **2) Em relação do corpus “shakespeare-hamlet.txt”, faça as seguintes atividades:**

# %% [markdown]
# # **a) Normalize o corpus (Retire os números e deixe todas as palavras minúsculas);**

# %%
#normalizando todas as sentenças em letra minuscula
minusculas = set(word.lower() for word in caesar if word.isalpha())
#toda palavra tem pelo menos 2 letras, isso tbm retira ",", "[", "!", "?", "." "outros caracteres", podem existir numeros de 2ddigitos ou mais, para isso temos a condição "isinstance(word, int) == False"
lista_sem_num = []
for word in minusculas:
  if (isinstance(word, int) == False):
      if re.search("..", word):
        lista_sem_num.append(word)

#minusculas
#lista_sem_num
print("Retire os números e deixe todas as palavras minúsculas: ", lista_sem_num)
# Out:
# Retire os números e deixe todas as palavras minúsculas:  ['trophees', 'meete', 'beside', 'cushions', 'almost', 'out', 'luc', 'darts', 'acquainted', 'honor', 'tag', 'seale', 'mistrust', 'creatures', 'mayest', 'lou', 'report', 'purpose', 'spouts', 'forme', 'hearse', 'schoole', 'cicero', 'greefe', 'diuided', 'abridg', 'annoy', 'cowardly', 'fearing', 'drizel', 'tops', 'murderers', 'blood', 'appeas', 'more', 'speak', 'garland', 'bath', 'pledge', 'mischiefe', 'construe', 'sinke', 'stirre', 'dispos', 'vniuersall', 'bankes', 'clamors', 'bargaine', 'youths', 'also', 'and', 'conditions', 'titinius', 'cuts', 'faine', 'eagles', 'loues', 'none', 'shriller', 'forgets', 'necessities', 'absent', 'go', 'vulgar', 'liberties', 'cryed', 'dismisse', 'repealing', 'lies', 'seeme', 'yon', 'aliue', 'knee', 'after', 'rage', 'swoonded', 'selfe', 'dwelling', 'modestie', 'proceede', 'canopy', 'honourably', 'threaten', 'neerer', 'lord', 'them', 'publius', 'sawcie', 'walles', 'depend', 'fulfill', 'constantly', 'sennit', 'lacke', 'veyl', 'ouer', 'expectation', 'heereafter', 'yond', 'sea', 'bright', 'entreated', 'doth', 'taper', 'companion', 'betweene', 'chance', 'pawse', 'contented', 'senslesse', 'brasse', 'tent', 'marching', 'oft', 'closet', 'fuller', 'sword', 'cob', 'flattered', 'farwell', 'patient', 'legacie', 'formall', 'incertaine', 'story', 'north', 'sounds', 'wash', 'receyuing', 'change', 'seem', 'calculate', 'smell', 'possible', 'lyes', 'husbanded', 'reioyce', 'malice', 'hearing', 'were', 'custome', 'inroll', 'sirra', 'speech', 'fields', 'ordinance', 'truly', 'security', 'pittifull', 'action', 'feathers', 'stricken', 'strucke', 'bleede', 'walking', 'soare', 'newes', 'distract', 'star', 'glories', 'tarrying', 'bird', 'conioyntly', 'iudge', 'third', 'scedule', 'ioynes', 'safely', 'loue', 'behold', 'bleeding', 'retentiue', 'parchment', 'diuers', 'motion', 'brauely', 'vertue', 'sake', 'ioy', 'gentlemen', 'compare', 'mock', 'asleepe', 'not', 'apace', 'roate', 'receiu', 'describ', 'intermit', 'receiuest', 'buried', 'destruction', 'cobler', 'king', 'winds', 'vowes', 'touch', 'deere', 'prey', 'enfranchisement', 'fellow', 'hide', 'becomes', 'fathers', 'vnicornes', 'vnluckily', 'we', 'crowes', 'squeale', 'braue', 'pleasures', 'shell', 'heart', 'two', 'remember', 'vse', 'shame', 'adde', 'obscurely', 'stronger', 'know', 'chidden', 'players', 'secrets', 'would', 'aule', 'make', 'hidden', 'fault', 'sicknesse', 'begg', 'enterred', 'twas', 'degrees', 'clouds', 'one', 'th', 'lyons', 'dec', 'walke', 'need', 'cursed', 'disconsolate', 'dimme', 'musing', 'sawce', 'watch', 'opinion', 'then', 'mee', 'sleeke', 'vnaccustom', 'ride', 'thinke', 'far', 'deale', 'enemie', 'obey', 'yoaked', 'fingers', 'censure', 'cancell', 'worships', 'weake', 'mace', 'exploit', 'inflame', 'weapons', 'lowest', 'ceremony', 'coronets', 'varrus', 'call', 'con', 'insurrection', 'climber', 'vrg', 'end', 'domesticke', 'song', 'endure', 'seeing', 'second', 'aye', 'strike', 'pipes', 'silence', 'vnnumbred', 'south', 'wonderfull', 'impatiently', 'enuy', 'seruile', 'sickely', 'pitty', 'particle', 'climb', 'chimney', 'euening', 'lost', 'vntyr', 'tyranny', 'hungry', 'hauocke', 'legions', 'incorporate', 'appearing', 'better', 'secundus', 'wafter', 'moou', 'trust', 'wenches', 'meales', 'flood', 'that', 'ensigne', 'infants', 'tell', 'ha', 'stands', 'hold', 'itching', 'vttermost', 'trash', 'bowl', 'brow', 'mid', 'immortall', 'drawing', 'lights', 'confounded', 'goe', 'speake', 'are', 'professe', 'full', 'cooling', 'vow', 'affection', 'opinions', 'genius', 'co', 'choice', 'vildely', 'writings', 'repeale', 'battaile', 'teare', 'pardon', 'throw', 'sirs', 'drop', 'disposed', 'followes', 'blest', 'beaten', 'trickes', 'rash', 'vnderlings', 'portentous', 'intreat', 'shoulder', 'boldest', 'pub', 'single', 'horrid', 'warriours', 'houres', 'thorough', 'costly', 'mindes', 'reply', 'factious', 'matters', 'fill', 'soundly', 'ragge', 'fasten', 'liberty', 'extremities', 'stra', 'addition', 'oakes', 'tune', 'bookes', 'range', 'fo ...

# %% [markdown]
# # **b) Aplique o lematizador em todas as palavras do corpus;**

# %%
import nltk 
nltk.download('wordnet') 
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
# Create WordNetLemmatizer object 
wnl = WordNetLemmatizer() 
  
# single word lemmatization examples 
listLematizar = nltk.corpus.gutenberg.words('shakespeare-caesar.txt')
listLematizar = set(word.lower() for word in listLematizar if word.isalpha())

#for words in listLematizar: 
    #print("Palavra não Lematizada: %%%%", words + " %%%% Palavra Lematiazada: " + wnl.lemmatize(words))

texto = str(listLematizar).strip('[]')
list2 = nltk.word_tokenize(texto)
lemmatized_string = ' '.join([wnl.lemmatize(words) for words in list2]) 

print("Lista Não Lematizada: ", list2) 
print("Lista Lematizada: ", lemmatized_string)

#Armazenador do lematizador
LemaSalvarDados = []
for word in list2:
    LemaSalvarDados.append(wnl.lemmatize(word))
print(LemaSalvarDados)
# Out:
# Lista Não Lematizada:  ['{', "'trophees", "'", ',', "'meete", "'", ',', "'beside", "'", ',', "'cushions", "'", ',', "'almost", "'", ',', "'out", "'", ',', "'luc", "'", ',', "'darts", "'", ',', "'acquainted", "'", ',', "'honor", "'", ',', "'tag", "'", ',', "'seale", "'", ',', "'mistrust", "'", ',', "'creatures", "'", ',', "'c", "'", ',', "'mayest", "'", ',', "'lou", "'", ',', "'report", "'", ',', "'purpose", "'", ',', "'spouts", "'", ',', "'forme", "'", ',', "'hearse", "'", ',', "'schoole", "'", ',', "'cicero", "'", ',', "'greefe", "'", ',', "'diuided", "'", ',', "'abridg", "'", ',', "'annoy", "'", ',', "'cowardly", "'", ',', "'fearing", "'", ',', "'drizel", "'", ',', "'tops", "'", ',', "'murderers", "'", ',', "'bl
', "'conioyntly", "'", ',', "'iudge", "'", ',', "'third", "'", ',', "'scedule", "'", ',', "'ioynes", "'", ',', "'safely", "'", ',', "'loue", "'", ',', "'behold", "'", ',', "'bleeding", "'", ',', "'retentiue", "'", ',', "'parchment", "'", ',', "'diuers", "'", ',', "'motion", "'", ',', "'brauely", "'", ',', "'vertue", "'", ',', "'sake", "'", ',', "'ioy", "'", ',', "'gentlemen", "'", ',', "'compare", "'", ',', "'mock", "'", ',', "'asleepe", "'", ',', "'not", "'", ',', "'apace", "'", ',', "'roat ...
# Lista Lematizada:  { 'trophees ' , 'meete ' , 'beside ' , 'cushions ' , 'almost ' , 'out ' , 'luc ' , 'darts ' , 'acquainted ' , 'honor ' , 'tag ' , 'seale ' , 'mistrust ' , 'creatures ' , 'c ' , 'mayest ' , 'lou ' , 'report ' , 'purpose ' , 'spouts ' , 'forme ' , 'hearse ' , 'schoole ' , 'cicero ' , 'greefe ' , 'diuided ' , 'abridg ' , 'annoy ' , 'cowardly ' , 'fearing ' , 'drizel ' , 'tops ' , 'murderers ' , 'blood ' , 'appeas ' , 'more ' , 'speak ' , 'garland ' , 'bath ' , 'pledge ' , 'mischiefe ' , 'construe ' , 'sinke ' , 'stirre ' , 'dispos ' , 'vniuersall ' , 'bankes ' , 'clamors ' , 'bargaine ' , 'youths ' , 'also ' , 'and ' , 'conditions ' , 'titinius ' , 'cuts ' , 'faine ' , 'eagles ' , 'loues ' , 'none ' , 'shriller ' , 'forgets ' , 'necessities ' , 'absent ' , 'go ' , 'vulgar ' , 'liberties ' , 'cryed ' , 'dismisse ' , 'repealing ' , 'lies ' , 'seeme ' , 'yon ' , 'aliue ' , 'knee ' , 'after ' , 'rage ' , 'swoonded ' , 'selfe ' , 'dwelling ' , 'modestie ' , 'proceede ' , 'canopy ' , 'honourably ' , 'threaten ' , 'neerer ' , 'lord ' , 'them ' , 'publius ' , 'sawcie ' , 'walles ' , 'depend ' , 'fulfill ' , 'constantly ' , 'sennit ' , 'lacke ' , 'veyl ' , 'ouer ' , 'expectation ' , 's ' , 'heereafter ' , 'yond ' , 'sea ' , 'bright ' , 'entreated ' , 'doth ' , 'taper ' , 'companion ' , 'betweene ' , 'chance ' , 'pawse ' , 'contented ' , 'senslesse ' , 'brasse ' , 'tent ' , 'marching ' , 'oft ' , 'closet ' , 'fuller ' , 'sword ' , 'cob ' , 'flattered ' , 'farwell ' , 'patient ' , 'legacie ' , 'formall ' , 'incertaine ' , 'story ' , 'north ' , 'sounds ' , 'wash ' , 'receyuing ' , 'change ' , 'seem ' , 'calculate ' , 'smell ' , 'possible ' , 'lyes ' , 'husbanded ' , 'reioyce ' , 'malice ' , 'hearing ' , 'were ' , 'custome ' , 'inroll ' , 'sirra ' , 'speech ' , 'fields ' , 'ordinance ' , 'truly ' , 'security ' , 'pittifull ' , 'action ' , 'feathers ' , 'stricken ' , 'strucke ' , 'bleede ' , 'walking ' , 'soare ' , 'newes ' , 'distract ' , 'star ' , 'glories ' , 'tarrying ' , 'bird ' , 'conioyntly ' , 'iudge ' , 'third ' , 'scedule ' , 'ioynes ' , 'safely ' , 'loue ' , 'behold ' , 'bleeding ' , 'retentiue ' , 'parchment ' , 'diuers ' , 'motion ' , 'brauely ' , 'vertue ' , 'sake ' , 'ioy ' , 'gentlemen ' , 'compare ' , 'mock ' , 'asleepe ' , 'not ' , 'apace ' , 'roate ' , 'receiu ' , 'describ ' , 'intermit ' , 'receiuest ' , 'buried ' , 'destruction ' , 'cobler ' , 'king ' , 'winds ' , 'vowes ' , 'touch ' , 'deere ' , 'prey ' , 'enfranchisement ' , 'fellow ' , 'hide ' , 'becomes ' , 'fathers ' , 'vnicornes ' , 'vnluckily ' , 'we ' , 'crowes ' , 'squeale ' , 'braue ' , 'pleasures ' , 'shell ' , 'heart ' , 'two ' , 'remember ' , 'vse ' , 'shame ' , 'adde ' , 'obscurely ' , 'stronger ' , 'know ' , 'chidden ' , 'players ' , 'secrets ' , 'would ' , 'aule ' , 'make ' , 'hidden ' , 'fault ' , 'sicknesse ' , 'begg ' , 'enterred ' , 't wa ' , 'degrees ' , 'clouds ' , 'one ' , 'th ' , 'lyons ' , 'dec ' , 'walke ' , 'need ' , 'cursed ' , 'disconsolate ' , 'dimme ' , 'musing ' , 'sawce ' , 'watch ' , 'opinion ' , 'then ' , 'mee ' , 'sleeke ' , 'vnaccustom ' , 'ride ' , 'thinke ' , 'far ' , 'deale ' , 'enemie ' , 'obey ' , 'yoaked ' , 'fingers ' , 'censure ' , 'cancell ' , 'worships ' , 'weake ' , 'mace ' , 'exploit ' , 'inflame ' , 'weapons ' , 'lowest ' , 'ceremony ' , 'coronets ' , 'varrus ' , 'call ' , 'con ' , 'insurrection ' , 'climber ' , 'vrg ' , 'end ' , 'domesticke ' , 'song ' , 'endure ' , 'seeing ' , 'second ' , 'aye ' , 'strike ' , 'pipes ' , 'silence ' , 'vnnumbred ' , 'south ' , 'wonderfull ' , 'impatiently ' , 'enuy ' , 'seruile ' , 'sickely ' , 'pitty ' , 'particle ' , 'climb ' , 'chimney ' , 'euening ' , 'lost ' , 'vntyr ' , 'tyranny ' , 'hungry ' , 'hauocke ' , 'legions ' , 'incorporate ' , 'appearing ' , 'better ' , 'secundus ' , 'wafter ' , 'moou ' , 'trust ' , 'wenches ' , 'meales ' , 'flood ' , 'that ' , 'ensigne ' , 'infants ' , 'tell ' , 'ha ' , 'stands ' , 'hold ' , 'itching ' , 'vttermost ' , 'trash ' , 'bowl '  ...
# ['{', "'trophees", "'", ',', "'meete", "'", ',', "'beside", "'", ',', "'cushions", "'", ',', "'almost", "'", ',', "'out", "'", ',', "'luc", "'", ',', "'darts", "'", ',', "'acquainted", "'", ',', "'honor", "'", ',', "'tag", "'", ',', "'seale", "'", ',', "'mistrust", "'", ',', "'creatures", "'", ',', "'c", "'", ',', "'mayest", "'", ',', "'lou", "'", ',', "'report", "'", ',', "'purpose", "'", ',', "'spouts", "'", ',', "'for
ittifull", "'", ',', "'action", "'", ',', "'feathers", "'", ',', "'stricken", "'", ',', "'strucke", "'", ',', "'bleede", "'", ',', "'walking", "'", ',', "'soare", "'", ',', "'newes", "'", ',', "'distract", "'", ',', "'star", "'", ',', "'glories", "'", ',', "'tarrying", "'", ',', "'bird", "'", ',', "'conioyntly", "'", ',', "'iudge", "'", ',', "'third", "'", ',', "'scedule", "'", ',', "'ioynes", "'", ',', "'safely", "'", ',', "'loue", "'", ',', "'behold", "'", ',', "'bleeding", "'", ',', "'retentiue", "'", ',', "'parchment", "'", ',', "'diuers", "'", ',', "'motion", "'", ',', "'brauely", "'", ',', "'vertue", "'", ',', "'sake", "'", ',', "'ioy", "'", ',', "'gentlemen", "'", ',', "'compare", "'", ',', "'mock", "'", ',', "'asleepe", "'", ',', "'not", "'", ',', "'apace", "'", ',', "'roate", "'", ',', "'receiu" ...

# %% [markdown]
# # **c) Aplique o tokenizador em todas as sentenças do corpus;**

# %%
tokens = [nltk.word_tokenize(str(comment)) for comment in minusculas]
print("tokenizador em todas as sentenças do corpus: ", tokens)
# Out:
# tokenizador em todas as sentenças do corpus:  [['trophees'], ['meete'], ['beside'], ['cushions'], ['almost'], ['out'], ['luc'], ['darts'], ['acquainted'], ['honor'], ['tag'], ['seale'], ['mistrust'], ['creatures'], ['c'], ['mayest'], ['lou'], ['report'], ['purpose'], ['spouts'], ['forme'], ['hearse'], ['schoole'], ['cicero'], ['greefe'], ['diuided'], ['abridg'], ['annoy'], ['cowardly'], ['fearing'], ['drizel'], ['tops'], ['murderers'], ['blood'], ['appeas'], ['more'], ['speak'], ['garland'], ['bath'], ['pledge'], ['mischiefe'], ['construe'], ['sinke'], ['stirre'], ['dispos'], ['vniuersall'], ['bankes'], ['clamors'], ['bargaine'], ['youths'], ['also'], ['and'], ['conditions'], ['titinius'], ['cuts'], ['faine'], ['eagles'], ['loues'], ['none'], ['shriller'], ['forgets'], ['necessities'], ['absent'], ['go'], ['vulgar'], ['liberties'], ['cryed'], ['dismisse'], ['repealing'], ['lies'], ['seeme'], ['yon'], ['aliue'], ['knee'], ['after'], ['rage'], ['swoonded'], ['selfe'], ['dwelling'], ['modestie'], ['proceede'], ['canopy'], ['honourably'], ['threaten'], ['neerer'], ['lord'], ['them'], ['publius'], ['sawcie'], ['walles'], ['depend'], ['fulfill'], ['constantly'], ['sennit'], ['lacke'], ['veyl'], ['ouer'], ['expectation'], ['s'], ['heereafter'], ['yond'], ['sea'], ['bright'], ['entreated'], ['doth'], ['taper'], ['companion'], ['betweene'], ['chance'], ['pawse'], ['contented'], ['senslesse'], ['brasse'], ['tent'], ['marching'], ['oft'], ['closet'], ['fuller'], ['sword'], ['cob'], ['flattered'], ['farwell'], ['patient'], ['legacie'], ['formall'], ['incertaine'], ['story'], ['north'], ['sounds'], ['wash'], ['receyuing'], ['change'], ['seem'], ['calculate'], ['smell'], ['possible'], ['lyes'], ['husbanded'], ['reioyce'], ['malice'], ['hearing'], ['were'], ['custome'], ['inroll'], ['sirra'], ['speech'], ['fields'], ['ordinance'], ['truly'], ['security'], ['pittifull'], ['action'], ['feathers'], ['stricken'], ['strucke'], ['bleede'], ['walking'], ['soare'], ['newes'], ['distract'], ['star'], ['glories'], ['tarrying'], ['bird'], ['conioyntly'], ['iudge'], ['third'], ['scedule'], ['ioynes'], ['safely'], ['loue'], ['behold'], ['bleeding'], ['retentiue'], ['parchment'], ['diuers'], ['motion'], ['brauely'], ['vertue'], ['sake'], ['ioy'], ['gentlemen'], ['compare'], ['mock'], ['asleepe'], ['not'], ['apace'], ['roate'], ['receiu'], ['describ'], ['intermit'], ['receiuest'], ['buried'], ['destruction'], ['cobler'], ['king'], ['winds'], ['vowes'], ['touch'], ['deere'], ['prey'], ['enfranchisement'], ['fellow'], ['hide'], ['becomes'], ['fathers'], ['vnicornes'], ['vnluckily'], ['we'], ['crowes'], ['squeale'], ['braue'], ['pleasures'], ['shell'], ['heart'], ['two'], ['remember'], ['vse'], ['shame'], ['adde'], ['obscurely'], ['stronger'], ['know'], ['chidden'], ['players'], ['secrets'], ['would'], ['aule'], ['make'], ['hidden'], ['fault'], ['sicknesse'], ['begg'], ['enterred'], ['twas'], ['degrees'], ['clouds'], ['one'], ['th'], ['lyons'], ['dec'], ['walke'], ['need'], ['cursed'], ['disconsolate'], ['dimme'], ['musing'], ['sawce'], ['watch'], ['opinion'], ['then'], ['mee'], ['sleeke'], ['vnaccustom'], ['ride'], ['thinke'], ['far'], ['deale'], ['enemie'], ['obey'], ['yoaked'], ['fingers'], ['censure'], ['cancell'], ['worships'], ['weake'], ['mace'], ['exploit'], ['inflame'], ['weapons'], ['lowest'], ['ceremony'], ['coronets'], ['varrus'], ['call'], ['con'], ['insurrection'], ['climber'], ['vrg'], ['end'], ['domesticke'], ['song'], ['endure'], ['seeing'], ['second'], ['aye'], ['strike'], ['pipes'], ['silence'], ['vnnumbred'], ['south'], ['wonderfull'], ['impatiently'], ['enuy'], ['seruile'], ['sickely'], ['pitty'], ['particle'], ['climb'], ['chimney'], ['euening'], ['lost'], ['vntyr'], ['tyranny'], ['hungry'], ['hauocke'], ['legions'], ['incorporate'], ['appearing'], ['better'], ['secundus'], ['wafter'], ['moou'], ['trust'], ['wenches'], ['meales'], ['flood'], ['that'], ['ensigne'], ['infants'], ['tell'], ['ha'], ['stands'], ['hold'], ['itching'], ['vtterm ...

# %% [markdown]
# # **d) Aplique os pos tagger e responda a quantidade de adjetivos existem no corpus; Dica a tag de adjetivo é “JJ”**

# %%
texto = nltk.corpus.gutenberg.words('shakespeare-caesar.txt')
texto = set(word.lower() for word in texto if word.isalpha())
texto = [nltk.word_tokenize(str(comment)) for comment in texto]
texto = str(texto).strip('[]')
text_tag = nltk.pos_tag(nltk.word_tokenize(texto))

# %%
ListaPP1 = [word[1] for word in text_tag if word[1] == "JJ"]
print('quantidade de adjetivos existem no corpus:', len(ListaPP1))
# Out:
# quantidade de adjetivos existem no corpus: 676
